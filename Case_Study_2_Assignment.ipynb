# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from statsmodels.formula.api import ols

# %%
file_path = '/content/IMB737-XLS-ENG (1).xlsx'
sheet_name = 'Regression Data'
data = pd.read_excel(file_path, sheet_name=sheet_name)

# %%
descriptive_stats = pd.DataFrame({
    'Mean': data.mean(),
    'Median': data.median(),
    'Mode': data.mode().iloc[0]
})
print("Descriptive Statistics (Mean, Median, Mode):")
print(descriptive_stats)
# Out:
# Descriptive Statistics (Mean, Median, Mode):
#                                      Mean       Median      Mode
# loan_amount                  46580.374016      0.00000       0.0
# loan_repaid                      0.759843      1.00000       1.0
# crop_insured                     0.098425      0.00000       0.0
# years_of_exp_in_sericulture     17.055118     18.00000      20.0
# training_on_sericulture          0.297244      0.00000       0.0
# krishi_pond                      0.094488      0.00000       0.0
# borewell_recharge                0.015748      0.00000       0.0
# rain_harvesting                  0.007874      0.00000       0.0
# own_compost_manure               0.468504      0.00000       0.0
# own_vermi_compost                0.179134      0.00000       0.0
# trenching_mulching               0.185039      0.00000       0.0
# bio_fertilizers                  0.594488      1.00000       1.0
# mechanization                    0.651575      1.00000       1.0
# ...

# %%
IPA = ols('income_per_acre ~ loan_amount+loan_repaid+ crop_insured+ training_on_sericulture+ krishi_pond+ borewell_recharge+ rain_harvesting + own_compost_manure + own_vermi_compost + years_of_exp_in_sericulture',data=data).fit()
print("\n🔹 Regression Model Summary:")
print(IPA.summary())
# Out:
# 🔹 Regression Model Summary:
#                             OLS Regression Results
# ...
# Dep. Variable:        income_per_acre   R-squared:                       0.221
# Model:                            OLS   Adj. R-squared:                  0.205
# Method:                 Least Squares   F-statistic:                     14.09
# Date:                Mon, 17 Feb 2025   Prob (F-statistic):           4.82e-22
# Time:                        10:46:05   Log-Likelihood:                -6023.7
# No. Observations:                 508   AIC:                         1.207e+04
# Df Residuals:                     497   BIC:                         1.212e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# ...

# %%
aov= sm.stats.anova_lm(IPA, typ =1)
print(aov)
# Out:
#                                 df        sum_sq       mean_sq          F  \
# loan_amount                    1.0  5.620503e+10  5.620503e+10  47.133652
# loan_repaid                    1.0  1.859599e+10  1.859599e+10  15.594636
# crop_insured                   1.0  2.496004e+10  2.496004e+10  20.931539
# training_on_sericulture        1.0  3.912836e+10  3.912836e+10  32.813122
# krishi_pond                    1.0  1.604677e+08  1.604677e+08   0.134569
# borewell_recharge              1.0  2.535583e+09  2.535583e+09   2.126345
# rain_harvesting                1.0  5.699284e+08  5.699284e+08   0.477943
# own_compost_manure             1.0  5.630525e+09  5.630525e+09   4.721770
# own_vermi_compost              1.0  9.441443e+09  9.441443e+09   7.917613
# years_of_exp_in_sericulture    1.0  1.079250e+10  1.079250e+10   9.050610
# Residual                     497.0  5.926530e+11  1.192461e+09        NaN
#
#                                    PR(>F)
# ...
